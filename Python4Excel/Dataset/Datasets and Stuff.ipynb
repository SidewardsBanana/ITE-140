# %% [markdown]
# ## Imports Pandas As pd

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pandas Reads CSV File and Adds It To The Variable planets

# %%
planets = pd.read_csv("planets.csv")
planets
# Out:
#     Planet                                            Color  Mass (10^24kg)  \
# 0  Mercury                                             Grey           0.330
# 1    Venus                                   Brown and Grey           4.870
# 2    Earth                      Blue, Brown Green and White           5.970
# 3     Mars                               Red, Brown and Tan           0.642
# 4  Jupiter  Brown, Orange and Tan, with White cloud stripes        1898.000
# 5   Saturn                     Golden, Brown, and Blue-Grey         568.000
# 6   Uranus                                       Blue-Green          86.800
# 7  Neptune                                             Blue         102.000
#
#    Diameter (km)  Density (kg/m^3)  Surface Gravity(m/s^2)  \
# 0           4879              5429                     3.7
# 1          12104              5243                     8.9
# 2          12756              5514                     9.8
# ...

# %%
planets
# Out:
#     Planet                                            Color  Mass (10^24kg)  \
# 0  Mercury                                             Grey           0.330
# 1    Venus                                   Brown and Grey           4.870
# 2    Earth                      Blue, Brown Green and White           5.970
# 3     Mars                               Red, Brown and Tan           0.642
# 4  Jupiter  Brown, Orange and Tan, with White cloud stripes        1898.000
# 5   Saturn                     Golden, Brown, and Blue-Grey         568.000
# 6   Uranus                                       Blue-Green          86.800
# 7  Neptune                                             Blue         102.000
#
#    Diameter (km)  Density (kg/m^3)  Surface Gravity(m/s^2)  \
# 0           4879              5429                     3.7
# 1          12104              5243                     8.9
# 2          12756              5514                     9.8
# ...

# %% [markdown]
# ## Making Copy For Descriptive Statistics

# %%
ds_planets = planets.copy()

# %%
ds_planets
# Out:
#     Planet                                            Color  Mass (10^24kg)  \
# 0  Mercury                                             Grey           0.330
# 1    Venus                                   Brown and Grey           4.870
# 2    Earth                      Blue, Brown Green and White           5.970
# 3     Mars                               Red, Brown and Tan           0.642
# 4  Jupiter  Brown, Orange and Tan, with White cloud stripes        1898.000
# 5   Saturn                     Golden, Brown, and Blue-Grey         568.000
# 6   Uranus                                       Blue-Green          86.800
# 7  Neptune                                             Blue         102.000
#
#    Diameter (km)  Density (kg/m^3)  Surface Gravity(m/s^2)  \
# 0           4879              5429                     3.7
# 1          12104              5243                     8.9
# 2          12756              5514                     9.8
# ...

# %% [markdown]
# ### Adding All The Moons From Each Planet In Our Solar System

# %%
sum_moons = ds_planets["Number of Moons"].sum()

# %% [markdown]
# #### Shows How Many Moons

# %%
sum_moons
# Out:
# 205

# %%
plot_planets= planets.copy()

# %%
planets.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pandas Reads CSV File and Adds It To The Variable food

# %%
meat = pd.read_csv("Fat In Meat and Price.csv")

# %%
meat
# Out:
#           Meat  Type  Fat In Grams Per 100 Grams  Price Per lb (Harris Teeter)
# 0      Brisket  Beef                         7.0                          7.99
# 1       Salmon  Fish                        13.0                         10.99
# 2        Bacon  Pork                        42.0                          5.99
# 3  Flank Steak  Beef                         8.0                         10.99
# 4    Pork Chop  Pork                        14.0                          4.99
# 5         Tuna  Fish                         1.3                         16.99

# %% [markdown]
# # Make Copy For Grouping

# %%
group_meat = meat.copy()

# %%
group_meat
# Out:
#           Meat  Type  Fat In Grams Per 100 Grams  Price Per lb (Harris Teeter)
# 0      Brisket  Beef                         7.0                          7.99
# 1       Salmon  Fish                        13.0                         10.99
# 2        Bacon  Pork                        42.0                          5.99
# 3  Flank Steak  Beef                         8.0                         10.99
# 4    Pork Chop  Pork                        14.0                          4.99
# 5         Tuna  Fish                         1.3                         16.99

# %% [markdown]
# ## Adding The Fat From Each Type

# %%
group_meat.groupby(["Type"]).sum()
# Out:
#       Fat In Grams Per 100 Grams  Price Per lb (Harris Teeter)
# Type
# Beef                        15.0                         18.98
# Fish                        14.3                         27.98
# Pork                        56.0                         10.98

# %% [markdown]
# ### Inference: From The Meats I Chose, Pork Is A Really Fatty Food Compared To Beef and Fish

# %% [markdown]
# # Making A Copy For Pivoting and Melting

# %%
pm_meat = meat.copy()

# %%
pm_meat
# Out:
#           Meat  Type  Fat In Grams Per 100 Grams  Price Per lb (Harris Teeter)
# 0      Brisket  Beef                         7.0                          7.99
# 1       Salmon  Fish                        13.0                         10.99
# 2        Bacon  Pork                        42.0                          5.99
# 3  Flank Steak  Beef                         8.0                         10.99
# 4    Pork Chop  Pork                        14.0                          4.99
# 5         Tuna  Fish                         1.3                         16.99

# %%
pivot = pd.pivot_table(pm_meat,
                                index="Meat", columns="Type",
                                values="Price Per lb (Harris Teeter)", aggfunc="sum",
                                margins=True, margins_name="Total")

# %%
pivot
# Out:
# Type          Beef   Fish   Pork  Total
# Meat
# Bacon          NaN    NaN   5.99   5.99
# Brisket       7.99    NaN    NaN   7.99
# Flank Steak  10.99    NaN    NaN  10.99
# Pork Chop      NaN    NaN   4.99   4.99
# Salmon         NaN  10.99    NaN  10.99
# Tuna           NaN  16.99    NaN  16.99
# Total        18.98  27.98  10.98  57.94

# %%
plot_meat = meat.copy()

# %%
plot_meat.plot()
# Out:
# <AxesSubplot:>
